# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sbn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Set some Pandas' settings

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# # Import and analyze training data

# %%
train_data = pd.read_csv('train.csv')

# %%
train_data
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# 1      ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# 2      ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# 3      ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# 4      ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                         ...       ...        ...   ...      ...
# 79018  ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# 79019  ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# 79020  ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# 79021  ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# 79022  ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# ...

# %%
train_data.describe()
# Out:
#            latitude     longitude          year       week_no  \
# count  79023.000000  79023.000000  79023.000000  79023.000000
# mean      -1.891072     29.880155   2020.000000     26.000000
# std        0.694522      0.810375      0.816502     15.297155
# min       -3.299000     28.228000   2019.000000      0.000000
# 25%       -2.451000     29.262000   2019.000000     13.000000
# 50%       -1.882000     29.883000   2020.000000     26.000000
# 75%       -1.303000     30.471000   2021.000000     39.000000
# max       -0.510000     31.532000   2021.000000     52.000000
#
#        SulphurDioxide_SO2_column_number_density  \
# count                              64414.000000
# mean                                   0.000048
# std                                    0.000272
# min                                   -0.000996
# 25%                                   -0.000096
# 50%                                    0.000024
# 75%                                    0.000153
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %% [markdown]
# ##### Considering that we only have the UV data for 439 rows, we should probably drop that since it's an unreliable metric

# %%
grouped_data = train_data[['latitude', 'longitude', 'UvAerosolLayerHeight_aerosol_height']].groupby(['latitude', 'longitude']).count()
grouped_data
# Out:
#                     UvAerosolLayerHeight_aerosol_height
# latitude longitude
# -3.299   30.301                                       0
# -3.287   29.713                                       1
# -3.174   29.926                                       0
# -3.161   28.839                                       0
# -3.153   30.347                                       0
# ...                                                 ...
# -0.598   29.102                                       0
# -0.569   30.031                                       0
# -0.547   29.653                                       3
# -0.528   29.472                                       0
# -0.510   29.290                                       1
#
# [497 rows x 1 columns]

# %%
grouped_data[grouped_data['UvAerosolLayerHeight_aerosol_height']>0]
# Out:
#                     UvAerosolLayerHeight_aerosol_height
# latitude longitude
# -3.287   29.713                                       1
# -3.138   30.662                                       3
# -3.136   30.364                                       1
# -3.133   29.467                                       1
# -3.032   29.168                                       1
# ...                                                 ...
# -0.653   30.447                                       2
# -0.637   30.763                                       2
# -0.615   30.885                                       1
# -0.547   29.653                                       3
# -0.510   29.290                                       1
#
# [239 rows x 1 columns]

# %% [markdown]
# ##### Considering that less than 1% of rows have UV data and less than half of the combinations of latitud and longitude have at least 1 row with UV data, we'll have to drop it.

# %%
usable_data = train_data.drop(['UvAerosolIndex_absorbing_aerosol_index', 'UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle', 'UvAerosolLayerHeight_solar_zenith_angle', 'UvAerosolLayerHeight_aerosol_height'],axis=1)
usable_data
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# 1      ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# 2      ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# 3      ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# 4      ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                         ...       ...        ...   ...      ...
# 79018  ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# 79019  ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# 79020  ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# 79021  ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# 79022  ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# ...

# %%
usable_data.dropna(inplace=True)

# %% [markdown]
# ##### Let's first try creating a model using only the rows that contain all the fields, since we have so many (57209 rows).

# %% [markdown]
# ### Splitting train dataset into X and Y

# %%
x = usable_data.drop(['emission', 'ID_LAT_LON_YEAR_WEEK'], axis=1)

# %%
y = usable_data['emission']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %% [markdown]
# ## Defining parameters and training Gradient Boosting Regressor

# %% [markdown]
# ##### The following cells have been commented out because the model has already been built (after many hours of run time).

# %%
#reg = GradientBoostingRegressor(n_estimators=500,
                                #max_depth=None,
                                #learning_rate=0.02,
                                #min_samples_split=3)

# %%
#reg.fit(x_train, y_train)

# %% [markdown]
# ### Define function to load an existing model

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %%
import pickle

# %% [markdown]
# ### Import existing model

# %%
reg = read_pickle('C:/Users/aguvidau/Desktop/', 'Kaggle CompetitionGradientBoost1')

# %% [markdown]
# # Predict train data

# %%
y_predictions = reg.predict(x_test)

# %% [markdown]
# ### Evaluate performance (Through RMSE)

# %%
rmse_score = mean_squared_error(y_test, y_predictions, squared=False)

# %%
rmse_score
# Out:
# 14.254898930046373

# %% [markdown]
# ##### Visualize difference in values (Green = True value, Red = Predicted value).

# %%
sbn.lineplot(x=range(len(y_test)), y=y_test, color='Green')
sbn.lineplot(x=range(len(y_predictions)), y=y_predictions, color='Red')
# Out:
# <Axes: ylabel='emission'>

# %% [markdown]
# ### Save Machine Learning Model

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %%
#write_pickle('C:/Users/aguvidau/Desktop/Kaggle Competition', reg, 'GradientBoost1')

# %% [markdown]
# # Import test data

# %%
test_data = pd.read_csv('test.csv')
test_data
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2022_00    -0.510     29.290  2022        0
# 1      ID_-0.510_29.290_2022_01    -0.510     29.290  2022        1
# 2      ID_-0.510_29.290_2022_02    -0.510     29.290  2022        2
# 3      ID_-0.510_29.290_2022_03    -0.510     29.290  2022        3
# 4      ID_-0.510_29.290_2022_04    -0.510     29.290  2022        4
# ...                         ...       ...        ...   ...      ...
# 24348  ID_-3.299_30.301_2022_44    -3.299     30.301  2022       44
# 24349  ID_-3.299_30.301_2022_45    -3.299     30.301  2022       45
# 24350  ID_-3.299_30.301_2022_46    -3.299     30.301  2022       46
# 24351  ID_-3.299_30.301_2022_47    -3.299     30.301  2022       47
# 24352  ID_-3.299_30.301_2022_48    -3.299     30.301  2022       48
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                           NaN
# 1                                      0.000456
# ...

# %% [markdown]
# ### Drop UV columns

# %%
x_predict = test_data.drop(['ID_LAT_LON_YEAR_WEEK','UvAerosolIndex_absorbing_aerosol_index', 'UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle', 'UvAerosolLayerHeight_solar_zenith_angle', 'UvAerosolLayerHeight_aerosol_height'],axis=1)

# %%
x_predict.isnull()
# Out:
#        latitude  longitude   year  week_no  \
# 0         False      False  False    False
# 1         False      False  False    False
# 2         False      False  False    False
# 3         False      False  False    False
# 4         False      False  False    False
# ...         ...        ...    ...      ...
# 24348     False      False  False    False
# 24349     False      False  False    False
# 24350     False      False  False    False
# 24351     False      False  False    False
# 24352     False      False  False    False
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                          True
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 24348                                     False
# 24349                                      True
# ...

# %% [markdown]
# ### Fill NaN values with the mean for each column (the model can't accept NaNs).

# %%
new_data = x_predict.fillna(x_predict.mean())

# %%
new_data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2022        0
# 1        -0.510     29.290  2022        1
# 2        -0.510     29.290  2022        2
# 3        -0.510     29.290  2022        3
# 4        -0.510     29.290  2022        4
# ...         ...        ...   ...      ...
# 24348    -3.299     30.301  2022       44
# 24349    -3.299     30.301  2022       45
# 24350    -3.299     30.301  2022       46
# 24351    -3.299     30.301  2022       47
# 24352    -3.299     30.301  2022       48
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                      0.000014
# 1                                      0.000456
# 2                                      0.000161
# 3                                      0.000350
# 4                                     -0.000317
# ...                                         ...
# 24348                                 -0.000618
# 24349                                  0.000014
# ...

# %% [markdown]
# # Predict values for test data

# %%
y_predict = reg.predict(new_data)

# %%
submission_data = {'ID_LAT_LON_YEAR_WEEK': test_data['ID_LAT_LON_YEAR_WEEK'], 'emission':y_predict}
submission = pd.DataFrame(data=submission_data)

# %% [markdown]
# # Create submission file and save it

# %%
submission
# Out:
#            ID_LAT_LON_YEAR_WEEK   emission
# 0      ID_-0.510_29.290_2022_00   4.613845
# 1      ID_-0.510_29.290_2022_01   4.330166
# 2      ID_-0.510_29.290_2022_02   4.589620
# 3      ID_-0.510_29.290_2022_03   4.395711
# 4      ID_-0.510_29.290_2022_04   4.625761
# ...                         ...        ...
# 24348  ID_-3.299_30.301_2022_44  27.999282
# 24349  ID_-3.299_30.301_2022_45  27.555855
# 24350  ID_-3.299_30.301_2022_46  28.318028
# 24351  ID_-3.299_30.301_2022_47  27.871617
# 24352  ID_-3.299_30.301_2022_48  30.141569
#
# [24353 rows x 2 columns]

# %%
submission.to_csv('submission_v2.csv', index=False)
